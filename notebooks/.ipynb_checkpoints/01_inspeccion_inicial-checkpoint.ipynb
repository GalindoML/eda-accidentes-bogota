# %% [markdown]
# ## Leer los datos iniciales
# Importamos nuestro excel y damos un vistazo a las hojas que tiene

# %%
import pandas as pd

xls = pd.ExcelFile('../data/raw/datos-siniestros.xlsx')
print(xls.sheet_names)
# Out:
# ['Campos', 'Tabla de Contenido', 'Base Consolidada', 'Hoja 2', 'Hoja 3', 'Actores viales\xa0', 'Vehículos', 'Entorno y vía', 'Factores de riesgo']

# %% [markdown]
# ## Exploracion a la hoja 'Campos'
# Esta hoja parece describir los datos que vamos a encontrar, como un diccionario de datos.
# Aca una muestra de la hoja

# %%
insp_campos = pd.read_excel('../data/raw/datos-siniestros.xlsx', sheet_name='Campos')
print(insp_campos.iloc[:10, :5])
# Out:
#    Versión  No. IPAT  No. Caso        A. Información IPAT   Unnamed: 4
# 0      NaN       NaN       NaN  1. Organismos de tránsito  2. Gravedad
# 1      NaN       NaN       NaN                        NaN          NaN
# 2      NaN       NaN       NaN                        NaN          NaN
# 3      NaN       NaN       NaN                        NaN          NaN
# 4      NaN       NaN       NaN                        NaN   CON MUERTO
# 5      NaN       NaN       NaN                        NaN   CON HERIDO
# 6      NaN       NaN       NaN                        NaN   SOLO DAÑOS
# 7      NaN       NaN       NaN                        NaN          NaN
# 8      NaN       NaN       NaN                        NaN          NaN
# 9      NaN       NaN       NaN                        NaN          NaN

# %%
insp_hoja2 = pd.read_excel('../data/raw/datos-siniestros.xlsx', sheet_name='Hoja 2',header=None, nrows=30)
display(insp_hoja2.head(40))
# Out:
#      0                  1                    2                            3    \
# 0    NaN                VÍA                  NaN  ACTORES VIALES INVOLUCRADOS
# 1   CASO         PRINCIPAL            SECUNDARIA                           A1
# 2      1      AUTOPISTA SUR                KR 71                  MOTOCICLETA
# 3      5              CL 26                43 95                  MOTOCICLETA
# 4      6         DG 84B SUR              4C ESTE                    CONDUCTOR
# 5      8              KR 11               CL 100                    CONDUCTOR
# 6     10             KR 87B              59 28 S                    CONDUCTOR
# 7     11             CL 145               KR 101                  MOTOCICLETA
# 8     12              CL 72                   51                    CONDUCTOR
# 9     15              TV 17              64A SUR                    BICICLETA
# 10    16                NaN                  NaN                    CONDUCTOR
# ...

# %%
print(insp_campos.head(5))
# Out:
#    Versión  No. IPAT  No. Caso        A. Información IPAT   Unnamed: 4  \
# 0      NaN       NaN       NaN  1. Organismos de tránsito  2. Gravedad
# 1      NaN       NaN       NaN                        NaN          NaN
# 2      NaN       NaN       NaN                        NaN          NaN
# 3      NaN       NaN       NaN                        NaN          NaN
# 4      NaN       NaN       NaN                        NaN   CON MUERTO
#
#                            Unnamed: 5  \
# 0  3. Lugar o coordenadas geográficas
# 1                   Código de la ruta
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#                                     Unnamed: 6   Unnamed: 7 Unnamed: 8  \
# 0                                          NaN          NaN        NaN
# 1  Vía y kilómetro o sitio, dirección y ciudad  Coordenadas        NaN
# 2                                          NaN          NaN        NaN
# ...
